# %% [markdown]
# # Data Extraction
# This python file will download, process, and visualize the dataset in a tabular format and then store into a pickle file for easier usage.
#
# **Authors:** Kevin Lu, Shrusti Jain, Smeet Patel, Taobo Liao

# %% [markdown]
# # Imports and Graph Configurations

# %%
import pandas as pd
#%matplotlib notebook
import matplotlib.pyplot as plt

# %%
#for some reason, this needs to be in a separate cell
params={
    "font.size":15,
    "lines.linewidth":5,
}
plt.rcParams.update(params)

# %%
# !gdown 1enR3DLH7iDuI0mG8rV3Z21tPhdZZRXOv
# !gdown 1zeyltSH_KaN0qQCRCiZR8kXOG6VUXU9T
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1enR3DLH7iDuI0mG8rV3Z21tPhdZZRXOv
# From (redirected): https://drive.google.com/uc?id=1enR3DLH7iDuI0mG8rV3Z21tPhdZZRXOv&confirm=t&uuid=8e9d1442-d6be-40fd-86a4-8470a205ddea
# To: c:\Users\jain9\Predicting_LA_Crimes\src\train.pkl
#
#   0%|          | 0.00/224M [00:00<?, ?B/s]
#   0%|          | 1.05M/224M [00:00<00:23, 9.29MB/s]
#   2%|▏         | 3.67M/224M [00:00<00:13, 16.1MB/s]
#   3%|▎         | 6.29M/224M [00:00<00:11, 18.5MB/s]
#   4%|▍         | 8.39M/224M [00:00<00:11, 19.1MB/s]
#   5%|▍         | 11.0M/224M [00:00<00:10, 19.7MB/s]
#   6%|▌         | 13.1M/224M [00:00<00:10, 20.0MB/s]
#   7%|▋         | 15.2M/224M [00:00<00:10, 20.3MB/s]
#   8%|▊         | 17.8M/224M [00:00<00:09, 20.8MB/s]
#   9%|▉         | 19.9M/224M [00:01<00:10, 20.3MB/s]
#  10%|▉         | 22.0M/224M [00:01<00:09, 20.3MB/s]
#  11%|█         | 24.1M/224M [00:01<00:09, 20.3MB/s]
#  12%|█▏        | 26.2M/224M [00:01<00:09, 20.3MB/s]
#  13%|█▎        | 28.3M/224M [00:01<00:09, 20.4MB/s]
#  14%|█▎        | 30.4M/224M [00:01<00:09, 20.4MB/s]
#  15%|█▍        | 32.5M/224M [00:01<00:09, 19.5MB/s]
#  16%|█▌        | 35.1M/224M [00:01<00:09, 20.5MB/s]
#  17%|█▋        | 37.7M/224M [00:01<00:08, 21.1MB/s]
#  18%|█▊        | 40.4M/224M [00:02<00:08, 21.3MB/s]
#  19%|█▉        | 43.0M/224M [00:02<00:08, 21.3MB/s]
#  20%|██        | 45.6M/224M [00:02<00:08, 21.7MB/s]
#  22%|██▏       | 48.2M/224M [00:02<00:07, 22.1MB/s]
#  23%|██▎       | 50.9M/224M [00:02<00:07, 21.9MB/s]
#  24%|██▍       | 53.5M/224M [00:02<00:07, 21.9MB/s]
#  25%|██▌       | 56.1M/224M [00:02<00:07, 22.0MB/s]
#  26%|██▋       | 58.7M/224M [00:02<00:07, 21.9MB/s]
#  27%|██▋       | 61.3M/224M [00:02<00:07, 21.8MB/s]
#  29%|██▊       | 64.0M/224M [00:03<00:07, 22.0MB/s]
#  30%|██▉       | 66.6M/224M [00:03<00:07, 22.0MB/s]
#  31%|███       | 69.2M/224M [00:03<00:07, 21.9MB/s]
#  32%|███▏      | 71.8M/224M [00:03<00:06, 22.0MB/s]
#  33%|███▎      | 74.4M/224M [00:03<00:07, 20.9MB/s]
#  34%|███▍      | 77.1M/224M [00:03<00:06, 21.6MB/s]
#  36%|███▌      | 79.7M/224M [00:03<00:06, 21.3MB/s]
#  37%|███▋      | 82.3M/224M [00:03<00:06, 21.8MB/s]
#  38%|███▊      | 84.9M/224M [00:04<00:06, 21.9MB/s]
#  39%|███▉      | 87.6M/224M [00:04<00:06, 21.8MB/s]
#  40%|████      | 90.2M/224M [00:04<00:06, 22.1MB/s]
#  42%|████▏     | 92.8M/224M [00:04<00:05, 21.8MB/s]
#  43%|████▎     | 95.4M/224M [00:04<00:05, 21.8MB/s]
#  44%|████▍     | 98.0M/224M [00:04<00:05, 22.1MB/s]
#  45%|████▌     | 101M/224M [00:04<00:05, 21.9MB/s]
#  46%|████▌     | 103M/224M [00:04<00:05, 21.9MB/s]
#  47%|████▋     | 106M/224M [00:05<00:05, 21.9MB/s]
#  49%|████▊     | 109M/224M [00:05<00:05, 22.0MB/s]
#  50%|████▉     | 111M/224M [00:05<00:05, 21.8MB/s]
#  51%|█████     | 114M/224M [00:05<00:05, 21.3MB/s]
#  52%|█████▏    | 116M/224M [00:05<00:04, 21.7MB/s]
#  53%|█████▎    | 119M/224M [00:05<00:04, 21.6MB/s]
#  54%|█████▍    | 122M/224M [00:05<00:04, 21.5MB/s]
#  56%|█████▌    | 124M/224M [00:05<00:04, 21.8MB/s]
#  57%|█████▋    | 127M/224M [00:05<00:04, 21.9MB/s]
#  58%|█████▊    | 129M/224M [00:06<00:04, 21.5MB/s]
#  59%|█████▉    | 132M/224M [00:06<00:04, 21.7MB/s]
#  60%|██████    | 135M/224M [00:06<00:04, 21.7MB/s]
#  61%|██████▏   | 137M/224M [00:06<00:03, 21.6MB/s]
#  63%|██████▎   | 140M/224M [00:06<00:03, 22.0MB/s]
#  64%|██████▍   | 143M/224M [00:06<00:03, 21.6MB/s]
#  65%|██████▍   | 145M/224M [00:06<00:03, 21.9MB/s]
#  66%|██████▌   | 148M/224M [00:06<00:03, 22.0MB/s]
#  67%|██████▋   | 150M/224M [00:07<00:03, 22.0MB/s]
#  68%|██████▊   | 153M/224M [00:07<00:03, 21.9MB/s]
#  70%|██████▉   | 156M/224M [00:07<00:03, 22.3MB/s]
#  71%|███████   | 158M/224M [00:07<00:02, 22.0MB/s]
#  72%|███████▏  | 161M/224M [00:07<00:02, 22.3MB/s]
#  73%|███████▎  | 164M/224M [00:07<00:02, 21.6MB/s]
#  74%|███████▍  | 166M/224M [00:07<00:02, 21.8MB/s]
#  76%|███████▌  | 169M/224M [00:07<00:02, 22.1MB/s]
#  77%|███████▋  | 171M/224M [00:08<00:02, 21.9MB/s]
#  78%|███████▊  | 174M/224M [00:08<00:02, 22.1MB/s]
#  79%|███████▉  | 177M/224M [00:08<00:02, 21.9MB/s]
#  80%|████████  | 179M/224M [00:08<00:01, 22.2MB/s]
#  81%|████████▏ | 182M/224M [00:08<00:01, 21.9MB/s]
#  83%|████████▎ | 185M/224M [00:08<00:01, 21.9MB/s]
#  84%|████████▎ | 187M/224M [00:08<00:01, 22.0MB/s]
#  85%|████████▍ | 190M/224M [00:08<00:01, 21.7MB/s]
#  86%|████████▌ | 192M/224M [00:08<00:01, 21.5MB/s]
#  87%|████████▋ | 195M/224M [00:09<00:01, 21.5MB/s]
#  88%|████████▊ | 198M/224M [00:09<00:01, 21.4MB/s]
#  90%|████████▉ | 200M/224M [00:09<00:01, 21.6MB/s]
#  91%|█████████ | 203M/224M [00:09<00:00, 21.7MB/s]
#  92%|█████████▏| 206M/224M [00:09<00:00, 21.5MB/s]
#  93%|█████████▎| 208M/224M [00:09<00:00, 21.7MB/s]
#  94%|█████████▍| 211M/224M [00:09<00:00, 21.8MB/s]
#  95%|█████████▌| 213M/224M [00:09<00:00, 22.1MB/s]
#  97%|█████████▋| 216M/224M [00:10<00:00, 21.7MB/s]
#  98%|█████████▊| 219M/224M [00:10<00:00, 17.5MB/s]
#  99%|█████████▊| 221M/224M [00:10<00:00, 16.8MB/s]
# 100%|█████████▉| 223M/224M [00:10<00:00, 18.0MB/s]
# 100%|██████████| 224M/224M [00:10<00:00, 21.2MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1zeyltSH_KaN0qQCRCiZR8kXOG6VUXU9T
# To: c:\Users\jain9\Predicting_LA_Crimes\src\debug.pkl
#
#   0%|          | 0.00/11.2M [00:00<?, ?B/s]
#   9%|▉         | 1.05M/11.2M [00:00<00:01, 8.82MB/s]
#  33%|███▎      | 3.67M/11.2M [00:00<00:00, 16.8MB/s]
#  51%|█████▏    | 5.77M/11.2M [00:00<00:00, 18.1MB/s]
#  75%|███████▍  | 8.39M/11.2M [00:00<00:00, 19.6MB/s]
#  93%|█████████▎| 10.5M/11.2M [00:00<00:00, 19.1MB/s]
# 100%|██████████| 11.2M/11.2M [00:00<00:00, 19.2MB/s]

# %% [markdown]
# # Data Extraction Sets

# %% [markdown]
# The dataset downloaded from the public website: https://catalog.data.gov/dataset/crime-data-from-2020-to-present has already been loaded and converted to a pickle file for easier storage.

# %%
crime_df = pd.read_pickle('train.pkl')

# %%
crime_df.columns
# Out:
# Index(['DR_NO', 'Date Rptd', 'DATE OCC', 'TIME OCC', 'AREA', 'AREA NAME',
#        'Rpt Dist No', 'Part 1-2', 'Crm Cd', 'Crm Cd Desc', 'Mocodes',
#        'Vict Age', 'Vict Sex', 'Vict Descent', 'Premis Cd', 'Premis Desc',
#        'Weapon Used Cd', 'Weapon Desc', 'Status', 'Status Desc', 'Crm Cd 1',
#        'Crm Cd 2', 'Crm Cd 3', 'Crm Cd 4', 'LOCATION', 'Cross Street', 'LAT',
#        'LON'],
#       dtype='object')

# %%
# Converts Date Rptd and DATE OCC columns from strings to datetime objects.
crime_df['Date Rptd'] = pd.to_datetime(crime_df['Date Rptd'], format='%m/%d/%Y %I:%M:%S %p')
crime_df['DATE OCC'] = pd.to_datetime(crime_df['DATE OCC'], format='%m/%d/%Y %I:%M:%S %p')
#crime_df['TIME OCC'] = pd.to_datetime(crime_df['TIME OCC'], format='')
#TIME OCC is not converted due to inconsistent/unknown format: eg TIME OCC at column 11 is merely '1'.

# %%
crime_df.head()
# Out:
#        DR_NO  Date Rptd   DATE OCC  TIME OCC  AREA  AREA NAME  Rpt Dist No  \
# 0  190326475 2020-03-01 2020-03-01      2130     7   Wilshire          784
# 1  200106753 2020-02-09 2020-02-08      1800     1    Central          182
# 2  200320258 2020-11-11 2020-11-04      1700     3  Southwest          356
# 3  200907217 2023-05-10 2020-03-10      2037     9   Van Nuys          964
# 4  220614831 2022-08-18 2020-08-17      1200     6  Hollywood          666
#
#    Part 1-2  Crm Cd                               Crm Cd Desc  ... Status  \
# 0         1     510                          VEHICLE - STOLEN  ...     AA
# 1         1     330                     BURGLARY FROM VEHICLE  ...     IC
# 2         1     480                             BIKE - STOLEN  ...     IC
# 3         1     343  SHOPLIFTING-GRAND THEFT ($950.01 & OVER)  ...     IC
# 4         2     354                         THEFT OF IDENTITY  ...     IC
#
#     Status Desc Crm Cd 1 Crm Cd 2  Crm Cd 3 Crm Cd 4  \
# 0  Adult Arrest    510.0    998.0       NaN      NaN
# 1   Invest Cont    330.0    998.0       NaN      NaN
# 2   Invest Cont    480.0      NaN       NaN      NaN
# 3   Invest Cont    343.0      NaN       NaN      NaN
# 4   Invest Cont    354.0      NaN       NaN      NaN
#
#                                    LOCATION Cross Street      LAT       LON
# 0   1900 S  LONGWOOD                     AV          NaN  34.0375 -118.3506
# 1   1000 S  FLOWER                       ST          NaN  34.0444 -118.2628
# 2   1400 W  37TH                         ST          NaN  34.0210 -118.3002
# 3  14000    RIVERSIDE                    DR          NaN  34.1576 -118.4387
# 4                         1900    TRANSIENT          NaN  34.0944 -118.3277
#
# [5 rows x 28 columns]

# %%
# Save two versions of the dataset in pickle format. The first
# 50,000 rows are saved to debug.pkl for debugging purposes,
# while the entire dataset is saved to train.pkl for training
# or further analysis.

debug_path = 'debug.pkl'
train_path = 'train.pkl'
crime_df[:50000].to_pickle(debug_path)
crime_df.to_pickle(train_path)
